# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## Cohort Retention Analysis — Olist E-Commerce
#
# **Цель:** понять как долго клиенты остаются активными после первой покупки и выявить паттерны удержания.
#
# **Датасет:** Brazilian E-Commerce Public Dataset (Olist) — 100k+ заказов.
#
# **Гипотеза:** большинство клиентов совершают только одну покупку — retention будет низким из-за специфики бизнес-модели (товары длительного пользования).
